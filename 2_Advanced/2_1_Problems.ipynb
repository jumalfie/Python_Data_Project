# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
df_cleaned = df.dropna(subset=['salary_year_avg'])
rows_after = len(df_cleaned)
rows_before = len(df)

rows_before, rows_after
# Out:
# (785741, 22003)

# %%
df_polished = df.drop_duplicates(subset=['job_location'])
rows_after = len(df_polished)
rows_before = df.shape[0]

rows_before, rows_after
# Out:
# (785741, 17218)

# %%
df_complete = df

df_complete['salary_rate'].fillna('Unknown').loc[:5]
# Out:
# 0    Unknown
# 1    Unknown
# 2    Unknown
# 3    Unknown
# 4    Unknown
# 5    Unknown
# Name: salary_rate, dtype: str

# %%
df['salary_rate'].head(5)
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: salary_rate, dtype: str
