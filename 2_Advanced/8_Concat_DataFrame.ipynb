# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
# Sample dataset of job postings in January
job_postings_jan = pd.DataFrame({
    'job_id': [1, 2, 3, 4, 5],
    'job_title': ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Data Scientist', 'Data Engineer'],
    'company': ['Company A', 'Company B', 'Company C', 'Company D', 'Company E'],
    'job_posted_date': pd.to_datetime(['2024-01-02', '2024-01-07', '2024-01-14', '2024-01-19', '2024-01-24'])
})

job_postings_jan
# Out:
#    job_id                  job_title    company job_posted_date
# 0       1             Data Scientist  Company A      2024-01-02
# 1       2               Data Analyst  Company B      2024-01-07
# 2       3  Machine Learning Engineer  Company C      2024-01-14
# 3       4             Data Scientist  Company D      2024-01-19
# 4       5              Data Engineer  Company E      2024-01-24

# %%
# Sample dataset of job postings in February
job_postings_feb = pd.DataFrame({
    'job_id': [6, 7, 8, 9, 10],
    'job_title': ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Data Scientist', 'Data Engineer'],
    'company': ['Company F', 'Company G', 'Company H', 'Company I', 'Company J'],
    'job_posted_date': pd.to_datetime(['2024-02-05', '2024-02-09', '2024-02-12', '2024-02-18', '2024-02-22'])
})

job_postings_feb
# Out:
#    job_id                  job_title    company job_posted_date
# 0       6             Data Scientist  Company F      2024-02-05
# 1       7               Data Analyst  Company G      2024-02-09
# 2       8  Machine Learning Engineer  Company H      2024-02-12
# 3       9             Data Scientist  Company I      2024-02-18
# 4      10              Data Engineer  Company J      2024-02-22

# %%
pd.concat([job_postings_jan, job_postings_feb], ignore_index= True)
# Out:
#    job_id                  job_title    company job_posted_date
# 0       1             Data Scientist  Company A      2024-01-02
# 1       2               Data Analyst  Company B      2024-01-07
# 2       3  Machine Learning Engineer  Company C      2024-01-14
# 3       4             Data Scientist  Company D      2024-01-19
# 4       5              Data Engineer  Company E      2024-01-24
# 5       6             Data Scientist  Company F      2024-02-05
# 6       7               Data Analyst  Company G      2024-02-09
# 7       8  Machine Learning Engineer  Company H      2024-02-12
# 8       9             Data Scientist  Company I      2024-02-18
# 9      10              Data Engineer  Company J      2024-02-22

# %%
df['job_posted_month'] = df['job_posted_date'].dt.strftime('%b')

# %%
months = df['job_posted_month'].unique()

months
# Out:
# <ArrowStringArray>
# ['Jun', 'Jan', 'Oct', 'Jul', 'Aug', 'Nov', 'Mar', 'Dec', 'Apr', 'Feb', 'Sep',
#  'May']
# Length: 12, dtype: str

# %%
dict_months = {month: df[df['job_posted_month'] == month] for month in months}

# %%
dict_months['Jan']
# Out:
#           job_title_short                                  job_title  \
# 1            Data Analyst                               Data Analyst
# 20         Data Scientist                             Data Scientist
# 39          Data Engineer                              Data Engineer
# 53          Data Engineer                              Data Engineer
# 55         Data Scientist                             Data Scientist
# ...                   ...                                        ...
# 785699  Software Engineer                        Simulation Engineer
# 785700      Data Engineer                       Data Engineer Ssr/Sr
# 785703       Data Analyst    Data Analyst - CRYPTOGRAPHY - Full-time
# 785704   Business Analyst                           Business Analyst
# 785705       Data Analyst  Expert Business Data Analyst - Now Hiring
#
#                                  job_location             job_via  \
# 1                Guadalajara, Jalisco, Mexico    via BeBee México
# 20                          Zaventem, Belgium  via BeBee Belgique
# 39                             Fort Worth, TX        via LinkedIn
# 53                              San Mateo, CA        via LinkedIn
# 55      São Paulo, State of São Paulo, Brazil           via BeBee
# ...                                       ...                 ...
# 785699                        Prague, Czechia     via Trabajo.org
# 785700              Mexico City, CDMX, Mexico     via Trabajo.org
# 785703                               Anywhere        via Snagajob
# 785704                        Prague, Czechia     via Trabajo.org
# 785705                            Oakland, CA        via Snagajob
#
#        job_schedule_type  job_work_from_home            search_location  \
# 1              Full-time               False                     Mexico
# 20             Full-time               False                    Belgium
# 39             Full-time               False       Texas, United States
# 53             Full-time               False  California, United States
# 55             Full-time               False                     Brazil
# ...                  ...                 ...                        ...
# 785699         Full-time               False                    Czechia
# 785700         Full-time               False                     Mexico
# 785703         Full-time                True       Texas, United States
# 785704         Full-time               False                    Czechia
# 785705         Full-time               False  California, United States
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 1      2023-01-14 13:18:07                  False                 False
# 20     2023-01-31 13:53:38                  False                 False
# 39     2023-01-25 13:24:01                  False                 False
# 53     2023-01-28 13:07:30                  False                  True
# 55     2023-01-03 23:02:27                  False                 False
# ...                    ...                    ...                   ...
# 785699 2023-01-16 06:35:30                  False                 False
# 785700 2023-01-12 06:19:55                   True                 False
# 785703 2023-01-28 06:02:55                   True                 False
# 785704 2023-01-16 06:35:20                  False                 False
# 785705 2023-01-09 06:00:25                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 1              Mexico         NaN              NaN              NaN
# 20            Belgium         NaN              NaN              NaN
# 39      United States         NaN              NaN              NaN
# 53      United States         NaN              NaN              NaN
# 55             Brazil         NaN              NaN              NaN
# ...               ...         ...              ...              ...
# 785699        Czechia         NaN              NaN              NaN
# 785700         Mexico         NaN              NaN              NaN
# 785703  United States         NaN              NaN              NaN
# 785704        Czechia         NaN              NaN              NaN
# 785705  United States         NaN              NaN              NaN
#
#                        company_name  \
# 1        Hewlett Packard Enterprise
# 20                         Devoteam
# 39                   Programmers.io
# 53                          Verkada
# 55                             Mars
# ...                             ...
# 785699        Ricardo Prague s.r.o.
# 785700                        Tsoft
# 785703  Axelon Services Corporation
# 785704                  Cleverlance
# 785705             PG&E Corporation
#
#                                                job_skills  \
# 1       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 20      ['r', 'python', 'sql', 'pandas', 'numpy', 'sci...
# 39                                      ['sql', 'python']
# 53                     ['sql', 'python', 'aws', 'looker']
# 55                             ['python', 'sql', 'azure']
# ...                                                   ...
# 785699                            ['powerpoint', 'excel']
# 785700  ['python', 'r', 'azure', 'aws', 'gcp', 'spark'...
# 785703                                                NaN
# 785704                                                NaN
# 785705                       ['sql', 'python', 'tableau']
#
#                                           job_type_skills job_posted_month
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...              Jan
# 20      {'libraries': ['pandas', 'numpy', 'scikit-lear...              Jan
# 39                     {'programming': ['sql', 'python']}              Jan
# 53      {'analyst_tools': ['looker'], 'cloud': ['aws']...              Jan
# 55      {'cloud': ['azure'], 'programming': ['python',...              Jan
# ...                                                   ...              ...
# 785699         {'analyst_tools': ['powerpoint', 'excel']}              Jan
# 785700  {'cloud': ['azure', 'aws', 'gcp'], 'libraries'...              Jan
# 785703                                                NaN              Jan
# 785704                                                NaN              Jan
# 785705  {'analyst_tools': ['tableau'], 'programming': ...              Jan
#
# [91822 rows x 18 columns]

# %%
quarter_1 = [dict_months['Jan'], dict_months['Feb'], dict_months['Mar']]

df_q1 = pd.concat(quarter_1, ignore_index=True)

df_q1
# Out:
#           job_title_short                                          job_title  \
# 0            Data Analyst                                       Data Analyst
# 1          Data Scientist                                     Data Scientist
# 2           Data Engineer                                      Data Engineer
# 3           Data Engineer                                      Data Engineer
# 4          Data Scientist                                     Data Scientist
# ...                   ...                                                ...
# 220479  Software Engineer                                    DevOps Engineer
# 220480       Data Analyst                                   CRM Data Analyst
# 220481   Business Analyst                     Commercial Analyst - Start Now
# 220482      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 220483  Software Engineer                                 AWS System Analyst
#
#                                  job_location                    job_via  \
# 0                Guadalajara, Jalisco, Mexico           via BeBee México
# 1                           Zaventem, Belgium         via BeBee Belgique
# 2                              Fort Worth, TX               via LinkedIn
# 3                               San Mateo, CA               via LinkedIn
# 4       São Paulo, State of São Paulo, Brazil                  via BeBee
# ...                                       ...                        ...
# 220479                              Singapura        melalui Trabajo.org
# 220480                     Bad Rodach, Jerman  melalui BeBee Deutschland
# 220481                               Malaysia           melalui Ricebowl
# 220482    Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 220483                                  India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home            search_location  \
# 0              Full-time               False                     Mexico
# 1              Full-time               False                    Belgium
# 2              Full-time               False       Texas, United States
# 3              Full-time               False  California, United States
# 4              Full-time               False                     Brazil
# ...                  ...                 ...                        ...
# 220479   Pekerjaan tetap               False                  Singapore
# 220480   Pekerjaan tetap               False                    Germany
# 220481   Pekerjaan tetap               False                   Malaysia
# 220482   Pekerjaan tetap               False                      Sudan
# 220483   Pekerjaan tetap               False                      India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0      2023-01-14 13:18:07                  False                 False
# 1      2023-01-31 13:53:38                  False                 False
# 2      2023-01-25 13:24:01                  False                 False
# 3      2023-01-28 13:07:30                  False                  True
# 4      2023-01-03 23:02:27                  False                 False
# ...                    ...                    ...                   ...
# 220479 2023-03-13 06:16:16                  False                 False
# 220480 2023-03-12 06:18:18                  False                 False
# 220481 2023-03-12 06:32:36                  False                 False
# 220482 2023-03-12 06:32:15                  False                 False
# 220483 2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0              Mexico         NaN              NaN              NaN
# 1             Belgium         NaN              NaN              NaN
# 2       United States         NaN              NaN              NaN
# 3       United States         NaN              NaN              NaN
# 4              Brazil         NaN              NaN              NaN
# ...               ...         ...              ...              ...
# 220479      Singapore         NaN              NaN              NaN
# 220480        Germany         NaN              NaN              NaN
# 220481       Malaysia         NaN              NaN              NaN
# 220482          Sudan         NaN              NaN              NaN
# 220483          India         NaN              NaN              NaN
#
#                               company_name  \
# 0               Hewlett Packard Enterprise
# 1                                 Devoteam
# 2                           Programmers.io
# 3                                  Verkada
# 4                                     Mars
# ...                                    ...
# 220479  CAREERSTAR INTERNATIONAL PTE. LTD.
# 220480                    HABA FAMILYGROUP
# 220481               Lendlease Corporation
# 220482                         Capital One
# 220483                              Trigyn
#
#                                                job_skills  \
# 0       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 1       ['r', 'python', 'sql', 'pandas', 'numpy', 'sci...
# 2                                       ['sql', 'python']
# 3                      ['sql', 'python', 'aws', 'looker']
# 4                              ['python', 'sql', 'azure']
# ...                                                   ...
# 220479  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 220480                     ['sas', 'sas', 'sql', 'excel']
# 220481                            ['powerpoint', 'excel']
# 220482  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 220483                                    ['aws', 'flow']
#
#                                           job_type_skills job_posted_month
# 0       {'analyst_tools': ['power bi', 'tableau'], 'pr...              Jan
# 1       {'libraries': ['pandas', 'numpy', 'scikit-lear...              Jan
# 2                      {'programming': ['sql', 'python']}              Jan
# 3       {'analyst_tools': ['looker'], 'cloud': ['aws']...              Jan
# 4       {'cloud': ['azure'], 'programming': ['python',...              Jan
# ...                                                   ...              ...
# 220479  {'os': ['linux', 'unix'], 'other': ['kubernete...              Mar
# 220480  {'analyst_tools': ['sas', 'excel'], 'programmi...              Mar
# 220481         {'analyst_tools': ['powerpoint', 'excel']}              Mar
# 220482  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...              Mar
# 220483              {'cloud': ['aws'], 'other': ['flow']}              Mar
#
# [220484 rows x 18 columns]

# %%
df_q1['job_posted_month'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='job_posted_month'>

# %% [markdown]
# ## Problems

# %%
data_scientist_df = df[df['job_title_short'] == 'Data Scientist']

data_analyst_df = df[df['job_title_short'] == 'Data Analyst']

# %%
combined_df = pd.concat([data_scientist_df, data_analyst_df], ignore_index=True)

combined_df
# Out:
#        job_title_short                                          job_title  \
# 0       Data Scientist                                  Data Scientist II
# 1       Data Scientist                             Data Science Team Lead
# 2       Data Scientist                                     Data Scientist
# 3       Data Scientist                                     Data Scientist
# 4       Data Scientist  Stage - data scientist – génération ia de donn...
# ...                ...                                                ...
# 368356    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 368357    Data Analyst          Expert Business Data Analyst - Now Hiring
# 368358    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 368359    Data Analyst                 Data & Analytics Architect (w/m/x)
# 368360    Data Analyst                                   CRM Data Analyst
#
#                       job_location  \
# 0                         Anywhere
# 1                       Laurel, MD
# 2         Pune, Maharashtra, India
# 3                Zaventem, Belgium
# 4       Asnières-sur-Seine, France
# ...                            ...
# 368356                    Anywhere
# 368357                 Oakland, CA
# 368358                       India
# 368359              Erfurt, Jerman
# 368360          Bad Rodach, Jerman
#
#                                                   job_via job_schedule_type  \
# 0                                        via ZipRecruiter         Full-time
# 1       via APL Careers - Johns Hopkins University App...         Full-time
# 2                                              via Indeed         Full-time
# 3                                      via BeBee Belgique         Full-time
# 4                                            via Jobijoba         Full-time
# ...                                                   ...               ...
# 368356                                       via Snagajob         Full-time
# 368357                                       via Snagajob         Full-time
# 368358  melalui Jobsleworld - Jobs In India - Job Vaca...   Pekerjaan tetap
# 368359                                   melalui LinkedIn   Pekerjaan tetap
# 368360                          melalui BeBee Deutschland   Pekerjaan tetap
#
#         job_work_from_home            search_location     job_posted_date  \
# 0                     True    New York, United States 2023-04-23 13:02:57
# 1                    False                    Georgia 2023-06-13 13:25:17
# 2                    False                      India 2023-04-26 13:20:12
# 3                    False                    Belgium 2023-01-31 13:53:38
# 4                    False                     France 2023-02-23 13:41:21
# ...                    ...                        ...                 ...
# 368356                True       Texas, United States 2023-01-28 06:02:55
# 368357               False  California, United States 2023-01-09 06:00:25
# 368358               False                      India 2023-03-13 06:16:28
# 368359               False                    Germany 2023-03-12 06:18:18
# 368360               False                    Germany 2023-03-12 06:18:18
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 0                       False                 False  United States
# 1                       False                  True  United States
# 2                       False                 False          India
# 3                       False                 False        Belgium
# 4                       False                 False         France
# ...                       ...                   ...            ...
# 368356                   True                 False  United States
# 368357                  False                 False  United States
# 368358                  False                 False          India
# 368359                  False                 False        Germany
# 368360                  False                 False        Germany
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 0              NaN              NaN              NaN
# 1              NaN              NaN              NaN
# 2              NaN              NaN              NaN
# 3              NaN              NaN              NaN
# 4              NaN              NaN              NaN
# ...            ...              ...              ...
# 368356         NaN              NaN              NaN
# 368357         NaN              NaN              NaN
# 368358         NaN              NaN              NaN
# 368359         NaN              NaN              NaN
# 368360         NaN              NaN              NaN
#
#                                     company_name  \
# 0                     Radwell International, LLC
# 1       Johns Hopkins Applied Physics Laboratory
# 2                              Bitwise Solutions
# 3                                       Devoteam
# 4                                Credit Agricole
# ...                                          ...
# 368356               Axelon Services Corporation
# 368357                          PG&E Corporation
# 368358                                      Amul
# 368359                             NTT DATA DACH
# 368360                          HABA FAMILYGROUP
#
#                                                job_skills  \
# 0       ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
# 1                                  ['go', 'apl', 'excel']
# 2       ['r', 'sql', 'python', 'scala', 'java', 'c++',...
# 3       ['r', 'python', 'sql', 'pandas', 'numpy', 'sci...
# 4                                                     NaN
# ...                                                   ...
# 368356                                                NaN
# 368357                       ['sql', 'python', 'tableau']
# 368358                                                NaN
# 368359                                   ['aws', 'azure']
# 368360                     ['sas', 'sas', 'sql', 'excel']
#
#                                           job_type_skills job_posted_month
# 0       {'analyst_tools': ['excel'], 'cloud': ['azure'...              Apr
# 1       {'analyst_tools': ['excel'], 'programming': ['...              Jun
# 2       {'analyst_tools': ['tableau'], 'libraries': ['...              Apr
# 3       {'libraries': ['pandas', 'numpy', 'scikit-lear...              Jan
# 4                                                     NaN              Feb
# ...                                                   ...              ...
# 368356                                                NaN              Jan
# 368357  {'analyst_tools': ['tableau'], 'programming': ...              Jan
# 368358                                                NaN              Mar
# 368359                        {'cloud': ['aws', 'azure']}              Mar
# 368360  {'analyst_tools': ['sas', 'excel'], 'programmi...              Mar
#
# [368361 rows x 18 columns]

# %%
df['job_posted_month'] = df['job_posted_date'].dt.strftime('%b')

# %%
months = df['job_posted_month'].unique()

month_dict = {month: df[df['job_posted_month'] == month] for month in months}

# %%
oct_df = month_dict['Oct']

Nov_df = month_dict['Dec']

Dec_df = month_dict['Dec']

# %%
q3_df = pd.concat([oct_df, Nov_df, Dec_df], ignore_index=True)

q3_df
# Out:
#          job_title_short                                          job_title  \
# 0          Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 1          Data Engineer                                      Data Engineer
# 2           Data Analyst                                       Data Analyst
# 3           Data Analyst                           Stage - Data Analyst F/H
# 4           Data Analyst  Data Analyst (Bangkok Based, relocation provided)
# ...                  ...                                                ...
# 179212     Data Engineer                                      Data Engineer
# 179213     Data Engineer                                      Data Engineer
# 179214      Data Analyst                                  Data Analyst Lead
# 179215  Business Analyst         Business Analysis and Intelligence Manager
# 179216    Cloud Engineer                             Engineer 3, Facilities
#
#                                              job_location  \
# 0                                         Berlin, Germany
# 1                                            Aberdeen, UK
# 2                                          Warsaw, Poland
# 3                                           Paris, France
# 4          Rome, Metropolitan City of Rome Capital, Italy
# ...                                                   ...
# 179212                          Ho Chi Minh City, Vietnam
# 179213                                 Gothenburg, Sweden
# 179214                                           Thailand
# 179215  Kuala Lumpur, Federal Territory of Kuala Lumpu...
# 179216                                   Penang, Malaysia
#
#                           job_via         job_schedule_type  \
# 0                    via LinkedIn                 Full-time
# 1                    via LinkedIn                 Temp work
# 2           via Praca Trabajo.org                 Full-time
# 3                    via LinkedIn  Full-time and Internship
# 4                    via LinkedIn                 Full-time
# ...                           ...                       ...
# 179212            via Trabajo.org                 Full-time
# 179213            via Trabajo.org                 Full-time
# 179214            via Trabajo.org                 Full-time
# 179215            via Trabajo.org                 Full-time
# 179216  via Smart Recruiters Jobs                 Full-time
#
#         job_work_from_home search_location     job_posted_date  \
# 0                    False         Germany 2023-10-10 13:14:55
# 1                    False  United Kingdom 2023-10-19 13:37:16
# 2                    False          Poland 2023-10-16 13:36:54
# 3                    False          France 2023-10-19 13:59:31
# 4                    False           Italy 2023-10-30 13:13:21
# ...                    ...             ...                 ...
# 179212               False         Vietnam 2023-12-17 06:23:18
# 179213               False          Sweden 2023-12-13 06:49:09
# 179214               False        Thailand 2023-12-17 06:16:04
# 179215               False        Malaysia 2023-12-05 06:22:35
# 179216               False        Malaysia 2023-12-21 06:12:22
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 0                       False                 False         Germany
# 1                       False                 False  United Kingdom
# 2                       False                 False          Poland
# 3                       False                 False          France
# 4                       False                 False           Italy
# ...                       ...                   ...             ...
# 179212                  False                 False         Vietnam
# 179213                  False                 False          Sweden
# 179214                  False                 False        Thailand
# 179215                  False                 False        Malaysia
# 179216                  False                 False        Malaysia
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 0              NaN              NaN              NaN
# 1              NaN              NaN              NaN
# 2              NaN              NaN              NaN
# 3              NaN              NaN              NaN
# 4              NaN              NaN              NaN
# ...            ...              ...              ...
# 179212         NaN              NaN              NaN
# 179213         NaN              NaN              NaN
# 179214         NaN              NaN              NaN
# 179215         NaN              NaN              NaN
# 179216         NaN              NaN              NaN
#
#                                              company_name  \
# 0                                ALPHA Augmented Services
# 1                                             Orion Group
# 2                                                   Glovo
# 3       GROUPE BON MARCHÉ : Le Bon Marché Rive Gauche ...
# 4                                                   Agoda
# ...                                                   ...
# 179212                                              Fram^
# 179213                                          Avigna AB
# 179214                               Siam Piwat Co., Ltd.
# 179215                                 Denave (M) Sdn Bhd
# 179216                                    Western Digital
#
#                                                job_skills  \
# 0       ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 1                           ['python', 'sql', 'power bi']
# 2       ['sql', 'python', 'r', 'redshift', 'pandas', '...
# 3                                                 ['sql']
# 4       ['sas', 'sas', 'r', 'python', 'vba', 'sql', 'j...
# ...                                                   ...
# 179212  ['sql', 'nosql', 'postgresql', 'mysql', 'spark...
# 179213                                                NaN
# 179214  ['sql', 'python', 'pyspark', 'excel', 'spreads...
# 179215  ['sql', 'sql server', 'excel', 'word', 'power ...
# 179216                                                NaN
#
#                                           job_type_skills job_posted_month
# 0       {'analyst_tools': ['dax'], 'cloud': ['azure'],...              Oct
# 1       {'analyst_tools': ['power bi'], 'programming':...              Oct
# 2       {'analyst_tools': ['excel', 'looker', 'tableau...              Oct
# 3                                {'programming': ['sql']}              Oct
# 4       {'analyst_tools': ['sas', 'spss', 'tableau', '...              Oct
# ...                                                   ...              ...
# 179212  {'databases': ['postgresql', 'mysql'], 'librar...              Dec
# 179213                                                NaN              Dec
# 179214  {'analyst_tools': ['excel', 'spreadsheet'], 'l...              Dec
# 179215  {'analyst_tools': ['excel', 'word', 'power bi'...              Dec
# 179216                                                NaN              Dec
#
# [179217 rows x 18 columns]

# %%
Full_time_df = df[df['job_schedule_type'] == 'Full-time']

part_time_df = df[df['job_schedule_type'] == 'Part-time']

# %%
combined_df = pd.concat([Full_time_df, part_time_df], ignore_index=True)

combined_df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 709603         Data Engineer
# 709604  Senior Data Engineer
# 709605        Data Scientist
# 709606      Business Analyst
# 709607        Data Scientist
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 709603                                     Data Engineer*
# 709604                               Senior Data Engineer
# 709605     Математик, Junior/Middle/Senior Data Scientist
# 709606                                            Analyst
# 709607  Consultant Data Science & berufsbegleitender M...
#
#                         job_location             job_via job_schedule_type  \
# 0                      Watertown, CT     via Work Nearby         Full-time
# 1       Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2                    Berlin, Germany        via LinkedIn         Full-time
# 3                    San Antonio, TX   via Diversity.com         Full-time
# 4                     Washington, DC  via Clearance Jobs         Full-time
# ...                              ...                 ...               ...
# 709603            Karlsruhe, Germany           via BeBee         Part-time
# 709604               Porto, Portugal  via BeBee Portugal         Part-time
# 709605                      Anywhere       via Rabota.by         Part-time
# 709606                      Anywhere        via LinkedIn         Part-time
# 709607               Munich, Germany      via Monster.de         Part-time
#
#         job_work_from_home       search_location     job_posted_date  \
# 0                    False  Texas, United States 2023-06-16 13:44:15
# 1                    False                Mexico 2023-01-14 13:18:07
# 2                    False               Germany 2023-10-10 13:14:55
# 3                    False  Texas, United States 2023-07-04 13:01:41
# 4                    False                 Sudan 2023-08-07 14:29:36
# ...                    ...                   ...                 ...
# 709603               False               Germany 2023-10-31 06:11:43
# 709604               False              Portugal 2023-10-04 06:16:58
# 709605                True               Belarus 2023-01-30 06:45:28
# 709606                True                 India 2023-05-21 06:00:44
# 709607               False               Germany 2023-01-15 06:20:06
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 0                       False                 False  United States
# 1                       False                 False         Mexico
# 2                       False                 False        Germany
# 3                        True                 False  United States
# 4                       False                 False          Sudan
# ...                       ...                   ...            ...
# 709603                  False                 False        Germany
# 709604                   True                 False       Portugal
# 709605                  False                 False        Belarus
# 709606                  False                 False          India
# 709607                  False                 False        Germany
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 0              NaN              NaN              NaN
# 1              NaN              NaN              NaN
# 2              NaN              NaN              NaN
# 3              NaN              NaN              NaN
# 4              NaN              NaN              NaN
# ...            ...              ...              ...
# 709603         NaN              NaN              NaN
# 709604         NaN              NaN              NaN
# 709605         NaN              NaN              NaN
# 709606         NaN              NaN              NaN
# 709607         NaN              NaN              NaN
#
#                                              company_name  \
# 0                                    Boehringer Ingelheim
# 1                              Hewlett Packard Enterprise
# 2                                ALPHA Augmented Services
# 3                            Southwest Research Institute
# 4                                         Kristina Daniel
# ...                                                   ...
# 709603                                 Robert Bosch Group
# 709604                         Diconium Digital Solutions
# 709605  Представительство ООО «Квалитет» (Российская Ф...
# 709606                      Blu Ocean Innovations pvt ltd
# 709607                                      Workwise GmbH
#
#                                                job_skills  \
# 0                                                     NaN
# 1       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2       ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4       ['bash', 'python', 'oracle', 'aws', 'ansible',...
# ...                                                   ...
# 709603             ['python', 'sql', 'spark', 'power bi']
# 709604  ['python', 'sql', 'java', 'aws', 'azure', 'red...
# 709605                               ['python', 'matlab']
# 709606                                                NaN
# 709607           ['python', 'java', 'snowflake', 'azure']
#
#                                           job_type_skills job_posted_month
# 0                                                     NaN              Jun
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...              Jan
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...              Oct
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...              Jul
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...              Aug
# ...                                                   ...              ...
# 709603  {'analyst_tools': ['power bi'], 'libraries': [...              Oct
# 709604  {'cloud': ['aws', 'azure', 'redshift'], 'libra...              Oct
# 709605              {'programming': ['python', 'matlab']}              Jan
# 709606                                                NaN              May
# 709607  {'cloud': ['snowflake', 'azure'], 'programming...              Jan
#
# [709608 rows x 18 columns]
