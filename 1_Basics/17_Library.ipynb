# %%
file = open('sample_data/california_housing_train.csv')

# %%
content = file.read()

file.close()

# %%
import pandas as pd

contents = pd.read_csv('sample_data/california_housing_train.csv')

contents['total_bedrooms'].sum()
# Out:
# np.float64(9169984.0)

# %%
! pip install pandas

# %%
! pip list
# Out:
# Package                               Version
# ------------------------------------- ------------------
# absl-py                               1.4.0
# accelerate                            1.14.0
# access                                1.1.10.post3
# affine                                2.4.0
# aiofiles                              25.1.0
# aiohappyeyeballs                      2.7.1
# aiohttp                               3.14.1
# aiosignal                             1.4.0
# aiosqlite                             0.22.1
# alabaster                             1.0.0
# albucore                              0.0.24
# albumentations                        2.0.8
# ale-py                                0.12.0
# altair                                5.5.0
# annotated-doc                         0.0.4
# annotated-types                       0.7.0
# antlr4-python3-runtime                4.9.3
# anyio                                 4.14.2
# anywidget                             0.9.21
# ...

# %%
! pip install pyjokes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 kB 746.6 kB/s eta 0:00:00
# ...

# %%
import pyjokes

# %%
help(pyjokes)
# Out:
# Help on package pyjokes:
#
# NAME
#     pyjokes
#
# PACKAGE CONTENTS
#     cli (package)
#     exc
#     jokes_cs
#     jokes_de
#     jokes_en
#     jokes_es
#     jokes_eu
#     jokes_fr
#     jokes_gl
#     jokes_hu
#     jokes_it
#     jokes_lt
#     jokes_pl
#     jokes_ru
#     jokes_sv
#     pyjokes
#
# DATA
#     CATEGORY_VALUES = {'all', 'chuck', 'neutral'}
#     LANGUAGE_VALUES = {'cs', 'de', 'en', 'es', 'eu', 'fr', ...}
#
# FILE
#     /usr/local/lib/python3.12/dist-packages/pyjokes/__init__.py

# %%
pyjokes.get_joke()
# Out:
# "I had a problem so I thought I'd use Java. Now I have a ProblemFactory."

# %% [markdown]
# # Problems

# %%
# !pip list
# Out:
# Package                               Version
# ------------------------------------- ------------------
# absl-py                               1.4.0
# accelerate                            1.14.0
# access                                1.1.10.post3
# affine                                2.4.0
# aiofiles                              25.1.0
# aiohappyeyeballs                      2.7.1
# aiohttp                               3.14.1
# aiosignal                             1.4.0
# aiosqlite                             0.22.1
# alabaster                             1.0.0
# albucore                              0.0.24
# albumentations                        2.0.8
# ale-py                                0.12.0
# altair                                5.5.0
# annotated-doc                         0.0.4
# annotated-types                       0.7.0
# antlr4-python3-runtime                4.9.3
# anyio                                 4.14.2
# anywidget                             0.9.21
# ...

# %%
import os
files = os.listdir('.')
for file in files:
    print(file)
# Out:
# .config
# sample_data

# %%
import requests

url = 'https://pokeapi.co/api/v2/pokemon/pikachu'

response = requests.get(url)
data = response.json()
print(data)
# Out:
# {'abilities': [{'ability': {'name': 'static', 'url': 'https://pokeapi.co/api/v2/ability/9/'}, 'is_hidden': False, 'slot': 1}, {'ability': {'name': 'lightning-rod', 'url': 'https://pokeapi.co/api/v2/ability/31/'}, 'is_hidden': True, 'slot': 3}], 'base_experience': 112, 'cries': {'latest': 'https://raw.githubusercontent.com/PokeAPI/cries/main/cries/pokemon/latest/25.ogg', 'legacy': 'https://raw.githubusercontent.com/PokeAPI/cries/main/cries/pokemon/legacy/25.ogg'}, 'forms': [{'name': 'pikachu', 'url': 'https://pokeapi.co/api/v2/pokemon-form/25/'}], 'game_indices': [{'game_index': 84, 'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}}, {'game_index': 84, 'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}}, {'game_index': 84, 'version': {'name': 'yellow', 'url': 'https://pokeapi.co/api/v2/version/3/'}}, {'game_index': 25, 'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}}, {'game_index': 25, 'version': {'name': 'sil
# ...
