# %% [markdown]
# # Objects: The Data Records

# %%
salary = 100000

# %%
100000
# Out:
# 100000

# %%
salary
# Out:
# 100000

# %%
type(salary)
# Out:
# int

# %%
"Data Analyst"
# Out:
# 'Data Analyst'

# %%
type("Data Analyst")
# Out:
# str

# %%
job_title = "Data Analyst"
job_location = "United States"
job_salary = 100000

# %%
id(job_title)
# Out:
# 132806985775152

# %%
id(job_location)
# Out:
# 132806985775408

# %%
job_1 = "Data Analyst"
job_2 = "Data Analyst"

# %%
id(job_1), id(job_2)
# Out:
# (132806983248368, 132806983239216)

# %%
job_3 = job_1

# %%
id(job_3), id(job_1)
# Out:
# (132806983248368, 132806983248368)

# %% [markdown]
# # Functions: Manipulation of objects
# Function: A reusable piece of code that performs a specific task.

# %%
print("What's up, Data Nerds?")
# Out:
# What's up, Data Nerds?

# %%
job_title = 'Data Scientist'

# %%
type(job_title)
# Out:
# str

# %%
job_title
# Out:
# 'Data Scientist'

# %%
salary = 85000.50

# %%
type(salary)
# Out:
# float

# %%
salary = 85000.50
print(type(salary))
# Out:
# <class 'float'>

# %%
salary_rate = 120000.75

# %%
salary_rate = int(salary_rate)

# %%
salary_rate
# Out:
# 120000

# %%
type(salary_rate)
# Out:
# int

# %%
print(type(salary_rate))
# Out:
# <class 'int'>

# %%
company_name = 'Data Inc.'

# %%
print(isinstance(company_name, str))
# Out:
# True

# %%
job_title = 'Data Scientist'
company_name = 'AI Solutions'
salary = 110000
bonus = salary * 0.1
total_compensation = salary + bonus

# %%
print(job_title, company_name, total_compensation)
# Out:
# Data Scientist AI Solutions 121000.0
