# %%
import random

salary_list = [random.randint(50000, 100000) for _ in range(1_000_000)]

# %%
import statistics

# %%
# %%timeit

statistics.mean(salary_list)
# Out:
# 438 ms ± 112 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import numpy as np

# %%
# %%timeit
np.mean(salary_list)
# Out:
# 85.9 ms ± 17.9 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
my_array = np.array([1,2,3,4])

# %%
my_array.mean()
# Out:
# np.float64(2.5)

# %%
import numpy as np

# %%
# job Title
job_titles = np.array(['Data Analyst', 'Data Scientist', 'Data Engineer', 'Machine Learning Engineer', 'AI Engineer'])

# Base salaries
base_salaries = np.array([60000, 80000, 75000, 90000, np.nan])

# Bonus rates
bonus_rates = np.array([.05, .1, .08, 0.12, np.nan])

# %%
total_salaries = base_salaries * (1 + bonus_rates)
total_salaries
# Out:
# array([ 63000.,  88000.,  81000., 100800.,     nan])

# %%
np.nanmean(total_salaries)
# Out:
# np.float64(83200.0)

# %% [markdown]
# # Problems

# %%
import numpy as np

# %%
application = np.array([10, 15, 7, 20, 25, 30, 5])

print(application)
# Out:
# [10 15  7 20 25 30  5]

# %%
postings_list = [10, 15, 7, 20, 25, 30, 5]

postings = np.array(postings_list[:3])

print(postings)
# Out:
# [10 15  7]

# %%
salaries_list = [70000, 85000, 60000, 95000, 80000]
salaries = np.array(salaries_list)
max_salary = np.max(salaries)
min_salary = np.min(salaries)

print(f"Maxmum salary is: {max_salary}")
print(f"Minimum salary is: {min_salary}")
# Out:
# Maxmum salary is: 95000
# Minimum salary is: 60000
