# %% [markdown]
# # Arithmentic Operators

# %%
2 + 3.0
# Out:
# 5.0

# %%
"What's" + " Up" + "!"
# Out:
# "What's Up!"

# %%
"What's Up? " * 10
# Out:
# "What's Up? What's Up? What's Up? What's Up? What's Up? What's Up? What's Up? What's Up? What's Up? What's Up? "

# %%
3.0 - 2
# Out:
# 1.0

# %%
5 / 2
# Out:
# 2.5

# %%
5 // 2
# Out:
# 2

# %%
5 % 2
# Out:
# 1

# %%
print("5 divided by 2 is", 5//2, "with a reminder of", 5 % 2)
# Out:
# 5 divided by 2 is 2 with a reminder of 1

# %% [markdown]
# # Order of Operations

# %%
max_salary = 80_000
min_salary = 20_000

avg_salary = (max_salary + min_salary) / 2
print(avg_salary)
# Out:
# 50000.0

# %% [markdown]
# # Assignment Operators

# %%
applicant_1 = "Kelly"
applicant_2 = "Luke"

# %%
applicant_1, applicant_2 = applicant_2, applicant_1

# %%
applicant_1, applicant_2
# Out:
# ('Luke', 'Kelly')

# %%
x = 1

# %%
x = x + 1

# %%
x
# Out:
# 2

# %%
x = 1
x += 1

# %%
x
# Out:
# 2

# %%
x = 2
x *= 3

# %%
x
# Out:
# 6

# %% [markdown]
# # Comparison Operators

# %%
salary_juma = 40_000
salary_mutua = 60_000

# %%
salary_juma == salary_mutua
# Out:
# False

# %%
1 == 1
# Out:
# True

# %%
if (salary_mutua > salary_juma):
  print("Mutua is paid more than Juma")
# Out:
# Mutua is paid more than Juma

# %% [markdown]
# # Problems

# %%
monthly_salary = 8000
annual_salary = 8000 * 12
annual_salary
# Out:
# 96000

# %%
avg_salary_analyst = 70000
avg_salary_scientist = 85000
check = avg_salary_analyst > avg_salary_scientist
print(check)
# Out:
# False

# %%
total_applications = 123
job_openings = 67
remainder = total_applications % job_openings
print(remainder)
# Out:
# 56

# %%
job_postings = 20
job_postings += 5
print(job_postings)
# Out:
# 25

# %%
min_salary = 50000
max_salary = 120000
avg_salary = (min_salary + max_salary) / 2
print(avg_salary)
# Out:
# 85000.0
