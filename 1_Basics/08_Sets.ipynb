# %%
job_skills = {'tableau', 'sql', 'python','statistics'}

# %%
job_skills
# Out:
# {'python', 'sql', 'statistics', 'tableau'}

# %%
job_skills.add('looker')

# %%
job_skills
# Out:
# {'looker', 'python', 'sql', 'statistics', 'tableau'}

# %%
job_skills.add('sql')

# %%
job_skills
# Out:
# {'looker', 'python', 'sql', 'statistics', 'tableau'}

# %%
job_skills.pop()
# Out:
# 'python'

# %%
job_skills.remove('statistics')

# %%
job_skills
# Out:
# {'looker', 'sql', 'tableau'}

# %%
skills_list = ['python', 'sql', 'tableau', 'statistics', "python", 'sql','tableau', 'statistics']

# %%
set(skills_list)
# Out:
# {'python', 'sql', 'statistics', 'tableau'}

# %%
list(set(skills_list))
# Out:
# ['sql', 'python', 'statistics', 'tableau']

# %% [markdown]
# # Problems

# %%
unique_job_titles = {'Data Scientist', 'Data Analyst', 'Machine Learning Engineer'}
unique_job_titles.add('AI Specialist')

print(unique_job_titles)
# Out:
# {'AI Specialist', 'Data Analyst', 'Data Scientist', 'Machine Learning Engineer'}

# %%
unique_job_titles = {'Data Scientist', 'Data Analyst', 'Machine Learning Engineer'}
unique_job_titles.remove('Data Analyst')

print(unique_job_titles)
# Out:
# {'Data Scientist', 'Machine Learning Engineer'}

# %%
job_locations = ['New York', 'San Francisco', 'New York', 'Austin', 'San Francisco']
set(job_locations)
# Out:
# {'Austin', 'New York', 'San Francisco'}

# %%
skills_set1 = {'Python', 'SQL', 'Tableau'}
skills_set2 = {'R', 'SQL', 'Machine Learning'}
skills_set1.union(skills_set2)
# Out:
# {'Machine Learning', 'Python', 'R', 'SQL', 'Tableau'}
