# %%
job_skills_type = {'database':'postgres',
                   'language': 'python',
                   'library': 'pandas'}

# %%
job_skills_type
# Out:
# {'database': 'postgres', 'language': 'python', 'library': 'pandas'}

# %%
job_skills_type['database']
# Out:
# 'postgres'

# %%
job_skills_type.keys()
# Out:
# dict_keys(['database', 'language', 'library'])

# %%
job_skills_type.values()
# Out:
# dict_values(['postgres', 'python', 'pandas'])

# %%
job_skills_type.pop('library')
# Out:
# 'pandas'

# %%
job_skills_type
# Out:
# {'database': 'postgres', 'language': 'python'}

# %%
job_skills_type.update({'cloud':"google cloud"})

# %%
job_skills_type
# Out:
# {'database': 'postgres', 'language': 'python', 'cloud': 'google cloud'}

# %%
job_skills_type['cloud']
# Out:
# 'google cloud'

# %%
job_skills_type['version_control'] = 'git'

# %%
job_skills_type
# Out:
# {'database': 'postgres',
#  'language': 'python',
#  'cloud': 'google cloud',
#  'version_control': 'git'}

# %% [markdown]
# # Problems

# %%
job_postings = {'Data Scientist': 120, 'Data Analyst': 80, 'Machine Learning Engineer': 50}
data_analyst_value = job_postings['Data Analyst']
print(data_analyst_value)
# Out:
# 80

# %%
job_postings = {'Data Scientist': 120, 'Data Analyst': 80, 'Machine Learning Engineer': 50}
job_postings['AI Specialist'] = '30'
print(job_postings)
# Out:
# {'Data Scientist': 120, 'Data Analyst': 80, 'Machine Learning Engineer': 50, 'AI Specialist': '30'}

# %%
job_postings = {'Data Scientist': 120, 'Data Analyst': 80, 'Machine Learning Engineer': 50}
job_postings.pop('Machine Learning Engineer')
print(job_postings)
# Out:
# {'Data Scientist': 120, 'Data Analyst': 80}

# %%
job_postings1 = {'Data Scientist': 120, 'Data Analyst': 80}
job_postings2 = {'Machine Learning Engineer': 50, 'AI Specialist': 30}
job_postings1.update(job_postings2)
print(job_postings1)
# Out:
# {'Data Scientist': 120, 'Data Analyst': 80, 'Machine Learning Engineer': 50, 'AI Specialist': 30}

# %%
job_details = {
    'Data Scientist': {'postings': 120, 'average_salary': 120000},
    'Data Analyst': {'postings': 80, 'average_salary': 80000},
    'Machine Learning Engineer': {'postings': 50, 'average_salary': 110000}
}
print(job_details)
# Out:
# {'Data Scientist': {'postings': 120, 'average_salary': 120000}, 'Data Analyst': {'postings': 80, 'average_salary': 80000}, 'Machine Learning Engineer': {'postings': 50, 'average_salary': 110000}}
