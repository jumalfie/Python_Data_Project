# %%
job_work_from_home = False
job_health_insurance = False
job_no_degree_mention = True

job_work_from_home or job_health_insurance or not job_no_degree_mention
# Out:
# False

# %% [markdown]
# # Membership Operators

# %%
"Data" in "Data Ners"
# Out:
# True

# %%
job_skills = ["python", 'sql', 'r']

# %%
'python' not in job_skills
# Out:
# False

# %% [markdown]
# # Identity Operators

# %%
salary_juma = 100_000
salary_mutua = 100_000

# %%
salary_juma == salary_mutua
# Out:
# True

# %%
id(salary_juma)
# Out:
# 139270678913136

# %%
id(salary_mutua)
# Out:
# 139270678911696

# %%
core_skills = ['python','r','sql']
juma_skills = core_skills

# %%
juma_skills is core_skills
# Out:
# True

# %% [markdown]
# # Problems

# %%
job_title1 = 'Data Engineer'
job_title2 = 'Data Engineer'

job_title1 is not job_title2
# Out:
# True

# %%
job_locations = ['New York', 'San Francisco', 'Austin']
'New York' in job_locations
# Out:
# True

# %%
job_title = 'Data Analyst'
job_description = 'Data Scientist at Tech Corp'

print(job_title is not job_description)
# Out:
# True

# %%
job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']
('Data Scientist'in job_titles and 'Machine Learning Engineer' in job_titles)
# Out:
# True

# %%
salary1 = 100000
salary2 = 50000

result = salary1 | salary2
print(result)
# Out:
# 116720
