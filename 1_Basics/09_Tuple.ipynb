# %%
juma_skills = ('python', 'sql', 'tableau', 'statistics')

# %%
juma_skills
# Out:
# ('python', 'sql', 'tableau', 'statistics')

# %%
juma_skills[0]
# Out:
# 'python'

# %%
juma_skills[0:2]
# Out:
# ('python', 'sql')

# %%
juma_skills = ('python', 'sql', 'tableau', 'statistics')
new_skills = ("excel", 'r')
juma_skills += new_skills
juma_skills
# Out:
# ('python', 'sql', 'tableau', 'statistics', 'excel', 'r')

# %% [markdown]
# Range()

# %%
range(5)
# Out:
# range(0, 5)

# %%
tuple(range(5))
# Out:
# (0, 1, 2, 3, 4)

# %%
tuple(range(2,5))
# Out:
# (2, 3, 4)

# %% [markdown]
# # Problems

# %%
job_roles = ('Data Scientist', 'Data Analyst', 'Machine Learning Engineer')
result = job_roles[1]
print(result)
# Out:
# Data Analyst

# %%
job_roles = ('Data Scientist', 'Data Analyst', 'Machine Learning Engineer')
new_role = ('AI Specialist',)
extended_job_roles = job_roles + new_role
print(extended_job_roles)
# Out:
# ('Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'AI Specialist')

# %%
job_roles = ('Data Scientist', 'Data Analyst', 'Machine Learning Engineer')

job_roles_list = list(job_roles)
job_roles_list.remove('Machine Learning Engineer')
job_roles = tuple(job_roles_list)
print(job_roles)
# Out:
# ('Data Scientist', 'Data Analyst')

# %%
job_postings = (120, 80, 50)
data_scientist_postings = job_postings[0]
data_analyst_postings = job_postings[1]
machine_learning_engineer_postings = job_postings[2]
print('Data Scientst Postings:', data_scientist_postings)
print('Data Analyst Postings:', data_analyst_postings)
print('Machine Learning Engineering Postings:', machine_learning_engineer_postings)
# Out:
# Data Scientst Postings: 120
# Data Analyst Postings: 80
# Machine Learning Engineering Postings: 50

# %%
job_details = (('Data Scientist', 120), ('Data Analyst', 80), ('Machine Learning Engineer', 50))
machine_learning_engineer_details = job_details[2][1]
machine_learning_engineer_details
# Out:
# 50
